# %%
# project 3 :- Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = pd.read_csv("C:/Users/ronak/OneDrive/Desktop/vehicle_dataset.csv")
plt.figure(figsize=(8,5))

# %%
#1. Bar Chart: Fuel Type Distribution
plt.figure(figsize=(8,5))
sns.countplot(x='Fuel_Type', data=df)

plt.title('Vehicle Count by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.show()

# %%
#2. Bar Chart: Transmission Distribution
plt.figure(figsize=(8,5))
sns.countplot(x='Transmission', data=df)

plt.title('Transmission Type Distribution')
plt.xlabel('Transmission')
plt.ylabel('Count')
plt.show()

# %%
#3. Histogram: Selling Price Distribution
plt.figure(figsize=(8,5))
plt.hist(df['Selling_Price'], bins=20)

plt.title('Selling Price Distribution')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.show()

# %%
#4. Histogram: Mileage (Kms Driven)
plt.figure(figsize=(8,5))
plt.hist(df['Kms_Driven'], bins=20)

plt.title('Mileage Distribution')
plt.xlabel('Kilometers Driven')
plt.ylabel('Frequency')
plt.show()

# %%
#5. Box Plot: Outlier Detection in Selling Price
plt.figure(figsize=(8,5))
sns.boxplot(y=df['Selling_Price'])

plt.title('Outlier Detection - Selling Price')
plt.show()

# %%
#6. Box Plot: Outlier Detection in Mileage
plt.figure(figsize=(8,5))
sns.boxplot(y=df['Kms_Driven'])

plt.title('Outlier Detection - Mileage')
plt.show()

# %%
#7. Scatter Plot: Mileage vs Selling Price
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='Kms_Driven',
    y='Selling_Price',
    data=df
)

plt.title('Mileage vs Selling Price')
plt.xlabel('Kilometers Driven')
plt.ylabel('Selling Price')
plt.show()

# %%
#8. Scatter Plot: Year vs Selling Price
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='Year',
    y='Selling_Price',
    data=df
)

plt.title('Vehicle Year vs Selling Price')
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.show()

# %%
#9. Correlation Heatmap
plt.figure(figsize=(8,6))

numeric_df = df.select_dtypes(include=['int64','float64'])

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')
plt.show()

# %%
#10. Top 10 Vehicle Brands by Count
top_brands = df['Car_Name'].value_counts().head(10)

plt.figure(figsize=(10,5))

top_brands.plot(kind='bar')

plt.title('Top 10 Vehicle Brands')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.show()
